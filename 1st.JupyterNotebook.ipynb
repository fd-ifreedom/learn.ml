# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Andrew Zhang</b>
# <br>
# Senior Engineer

# %% [markdown]
# <i>I am interested in data science because I want enhance my skills set and extend my job scope.</i>

# %% [markdown]
# <h3>for a simple calculation: 1+1=?</h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <hr>
# <ol>
#     <li>1+1=2</li>
#     <li>2+2=4</li>
# </ol>
# <ul>
#     <li>1+1=2</li>
#     <li>2+2=4</li>
# </ul>
# <table>
#     <tr>
#         <td>the 1st column</td>
#         <td>the 2nd column</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>3</td>
#     </tr>
#  </table>
